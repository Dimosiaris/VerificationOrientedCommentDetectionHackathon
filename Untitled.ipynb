# %%
import pandas as pd

# %%
data = pd.read_json('yt_meta.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-e1fc59d48f88> in <module>
# ----> 1 data = pd.read_json('yt_meta.json')
#
# /anaconda3/envs/Work/lib/python3.7/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# /anaconda3/envs/Work/lib/python3.7/site-packages/pandas/io/json/json.py in read(self)
#     535             )
#     536         else:
# --> 537             obj = self._get_object_parser(self.data)
#     538         self.close()
#     539         return obj
#
# ...

# %%
data.columns
# Out:
# Index(['_id', 'channel_about_page', 'channel_comment_count',
#        'channel_created_time', 'channel_description', 'channel_id',
#        'channel_location', 'channel_subscriber_count', 'channel_url',
#        'channel_video_count', 'channel_videos_per_month', 'channel_view_count',
#        'label', 'num_verification_comments', 'processing_status',
#        'reverse_image_thumbnails_search_url',
#        'reverse_image_thumbnails_search_url_google',
#        'reverse_image_thumbnails_search_url_yandex', 'target_video',
#        'twitter_search_url', 'verification_comments', 'video_author_comments',
#        'video_author_url_comments', 'video_comment_count', 'video_comments',
#        'video_definition', 'video_description', 'video_dimension',
#        'video_dislike_count', 'video_duration', 'video_favorite_count',
#        'video_id', 'video_licensed_content', 'video_like_count',
#        'video_publishedAt_comments', 'video_recording_location_description',
# ...

# %%
c_data = data[['_id','video_id','verification_comments','video_comments','video_author_comments']]

# %%
c_data
# Out:
#               _id     video_id  \
# 0     Y7MJlmbnLQA  Y7MJlmbnLQA
# 1     uqZeCGo0LnE  uqZeCGo0LnE
# 2     07kv4UTfqgE  07kv4UTfqgE
# 3     OfT-oZZPbtU  OfT-oZZPbtU
# 4     8kxyb0eDOWQ  8kxyb0eDOWQ
# 5     WP5hxAm8KnE  WP5hxAm8KnE
# 6     p4UfVh74JZ0  p4UfVh74JZ0
# 7     TEt6TWzbn8E  TEt6TWzbn8E
# 8     nTDud03nzCg  nTDud03nzCg
# 9     XSRhFjc--_s  XSRhFjc--_s
# 10    JrD4G14s_G8  JrD4G14s_G8
# 11    cuZluNkoDOU  cuZluNkoDOU
# 12    SOEG39R1Te0  SOEG39R1Te0
# 13    vhre0_9oRt4  vhre0_9oRt4
# 14    JOY8YRWir1A  JOY8YRWir1A
# 15    DP9zuwjcLEU  DP9zuwjcLEU
# 16    HQpRS4nqz20  HQpRS4nqz20
# 17    IIapO9MiVgk  IIapO9MiVgk
# 18    QN0tc4RhQnI  QN0tc4RhQnI
# 19    2VcdBuC0IPw  2VcdBuC0IPw
# 20    TYN02l_o0Xs  TYN02l_o0Xs
# 21    aGu_l5DHdm0  aGu_l5DHdm0
# 22    ZgNE8fX_aqs  ZgNE8fX_aqs
# 23    SGexweIR7e0  SGexweIR7e0
# 24    -wM2pa1A_io  -wM2pa1A_io
# 25    DnqJHZf-s6U  DnqJHZf-s6U
# 26    Xx_txfCN9TQ  Xx_txfCN9TQ
# 27    ambXFfG4_0c  ambXFfG4_0c
# 28    sm8qb2kP-fQ  sm8qb2kP-fQ
# ...

# %%
import requests
url = "https://www.googleapis.com/youtube/v3/commentThreads?key=AIzaSyBwVBaYAjsSyj19TLXmDuNoliSsKmA6oK0&textFormat=plainText&part=snippet&videoId=kffacxfA7G4&maxResults=10"
headers={'Accept':'application/json'}
r=requests.get(url,headers=headers)
d=r.json()
d['items']
data =pd.DataFrame.from_dict(d['items'],orient='columns')
data['snippet'][0]
# Out:
# {'videoId': 'kffacxfA7G4',
#  'topLevelComment': {'kind': 'youtube#comment',
#   'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/3QnZ3uYSCqG4ZLzlJcK5qq08XHg"',
#   'id': 'UgwQBJ_eLzhnc2VObCR4AaABAg',
#   'snippet': {'authorDisplayName': 'JM K',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/-OTaWZv7LMWM/AAAAAAAAAAI/AAAAAAAAAAA/-nKC8E55HqI/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#    'authorChannelUrl': 'http://www.youtube.com/channel/UCR6_n_P0KHtoYIRpGgipbKQ',
#    'authorChannelId': {'value': 'UCR6_n_P0KHtoYIRpGgipbKQ'},
#    'videoId': 'kffacxfA7G4',
#    'textDisplay': '💙💙💙💙🇸🇩💙💙💙🇸🇩 #مليونية13\n#سودآني_جد \n#عيد_شهيد \n #blue_for_sudan',
#    'textOriginal': '💙💙💙💙🇸🇩💙💙💙🇸🇩 #مليونية13\n#سودآني_جد \n#عيد_شهيد \n #blue_for_sudan',
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2019-07-16T14:00:16.000Z',
#    'updatedAt': '2019-07-16T14:00:16.000Z'}},
#  'canReply': True,
#  'totalReplyCount': 0,
#  'isPublic': True}

# %%
data.columns
# Out:
# Index(['etag', 'id', 'kind', 'snippet'], dtype='object')

# %%
data['snippet'][0]
# Out:
# {'videoId': 'GXs23OOCGW0',
#  'topLevelComment': {'kind': 'youtube#comment',
#   'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/hLhQ-zPmyL6Cyhn6eYkRCoq675I"',
#   'id': 'Ugxn5BpxwYdCceoGcsx4AaABAg',
#   'snippet': {'authorDisplayName': 'pavlos kerasidis',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/-6kuG9ukKq2M/AAAAAAAAAAI/AAAAAAAAAAA/bfwQqQtlSyk/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#    'authorChannelUrl': 'http://www.youtube.com/channel/UCqHCz7ycWoN6q2AEJ2ShDDg',
#    'authorChannelId': {'value': 'UCqHCz7ycWoN6q2AEJ2ShDDg'},
#    'videoId': 'GXs23OOCGW0',
#    'textDisplay': 'mpegmp m.. kses esi ❤️',
#    'textOriginal': 'mpegmp m.. kses esi ❤️',
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2019-07-14T16:58:08.000Z',
#    'updatedAt': '2019-07-14T16:58:08.000Z'}},
#  'canReply': True,
#  'totalReplyCount': 0,
#  'isPublic': True}

# %%
len(data['snippet'])
# Out:
# 100

# %%
comms
# Out:
#                                               snippet
# 0   {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# 1   {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# 2   {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# 3   {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# 4   {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# 5   {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# 6   {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# 7   {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# 8   {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# 9   {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# 10  {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# 11  {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# 12  {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# 13  {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# 14  {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# 15  {'videoId': 'GXs23OOCGW0', 'topLevelComment': ...
# ...

# %%
cols=['id','text','likes','replies']
comments=pd.DataFrame(columns=cols)
url="https://www.googleapis.com/youtube/v3/commentThreads?key=AIzaSyBwVBaYAjsSyj19TLXmDuNoliSsKmA6oK0&textFormat=plainText&part=snippet&videoId=Xd2fSGv6MPQ&maxResults=50"
headers={'Accept':'application/json'}
r=requests.get(url,headers=headers)
d=r.json()
ndata =pd.DataFrame.from_dict(d['items'],orient='columns')
thislist=[]
for i in range(len(ndata)):
    comment=ndata['snippet'][i]['topLevelComment']['snippet']
    comments.loc[len(comments)]=[ndata['snippet'][i]['topLevelComment']['id'],comment['textDisplay'],comment['likeCount'],ndata['snippet'][i]['totalReplyCount']]
if d['pageInfo']['totalResults']==50:
    nt=d['nextPageToken']
while nt:
    url="https://www.googleapis.com/youtube/v3/commentThreads?key=AIzaSyBwVBaYAjsSyj19TLXmDuNoliSsKmA6oK0&textFormat=plainText&part=snippet&videoId=Xd2fSGv6MPQ&maxResults=50"+'&pageToken='+nt
    headers={'Accept':'application/json'}
    r=requests.get(url,headers=headers)
    d=r.json()
    d['items']
    ndata =pd.DataFrame.from_dict(d['items'],orient='columns')
    thislist=[]
    for i in range(len(ndata)):
        comment=ndata['snippet'][i]['topLevelComment']['snippet']
        comments.loc[len(comments)]=[ndata['snippet'][i]['topLevelComment']['id'],comment['textDisplay'],comment['likeCount'],ndata['snippet'][i]['totalReplyCount']]
    if d['pageInfo']['totalResults']==50:
        nt=d['nextPageToken']
    else:
        break
comments
# Out:
#                              id  \
# 0    Ugw6dajv4pKnpASWnix4AaABAg
# 1    Ugzx2v9ueHxxLImn8lx4AaABAg
# 2    UgxJSDPIB9sNCo8Tg554AaABAg
# 3    UgxTatkBGRDjf1PjsHF4AaABAg
# 4    UgwJhPie5cuJd9B_hD14AaABAg
# 5    Ugy19gCEuHmsjAAQ4Bd4AaABAg
# 6    Ugx-lqWubrD6ZJWklQV4AaABAg
# 7    UgydonmJhaiZFt2WORN4AaABAg
# 8    UgzyVM1j6K6CnoIciVZ4AaABAg
# 9    UgwoyaaFhUDLVlJN1Qx4AaABAg
# 10   UgzBwfT6-iivJBzPvTl4AaABAg
# 11   Ugy-xPhH01YgOZrEW1R4AaABAg
# 12   UgxkYb1Wi9fJpouSdjp4AaABAg
# 13   UgyD3wGMSD2AAU53hth4AaABAg
# 14   UgwJzi8RWOsakA4CEKV4AaABAg
# 15   UgwNIXLtSZKkCB2IpNB4AaABAg
# 16   UgwliB2H6zfD2iTF0HF4AaABAg
# 17   UgwCk7_ItCB-7QTWf0R4AaABAg
# 18   UgzaIsKY_K3fL6CbFCx4AaABAg
# 19   UgwM34KTDYDjkS1G29R4AaABAg
# 20   UgydFrb8vwtRmhfBfyR4AaABAg
# 21   UgzBwyUO8cWZGXqhikR4AaABAg
# 22   Ugx9RhePSSjI6JDvOl54AaABAg
# 23   Ugz0hRZ5XX-bXbITi6l4AaABAg
# 24   UgylbiEgg5_Qtc-rV1h4AaABAg
# 25   UgzSBHn3FUXerzOu6RZ4AaABAg
# 26   UgwO9KBpNE6-Qj9Q-OF4AaABAg
# 27   UgxQeSrUwwmXwtPDg2J4AaABAg
# ...

# %%
https://www.googleapis.com/youtube/v3/commentThreads?key=AIzaSyBwVBaYAjsSyj19TLXmDuNoliSsKmA6oK0&textFormat=plainText&part=snippet&videoId=kffacxfA7G4&maxResults=10
# Out:
#   File "<ipython-input-21-de1f6ce98765>", line 1
#     https://www.googleapis.com/youtube/v3/commentThreads?key=AIzaSyBwVBaYAjsSyj19TLXmDuNoliSsKmA6oK0&textFormat=plainText&part=snippet&videoId=kffacxfA7G4&maxResults=10
#            ^
# SyntaxError: invalid syntax
